# %%
import pandas as pd

# %%
df = pd.read_csv("north_american_primary_data_semicolons.csv", sep=";")
df
# Out:
#           family                    name class cap-diameter  cap-shape  \
# 0    Amanitaceae        Amanita vaginata   [e]      [5, 10]  [c, x, f]
# 1    Amanitaceae   Saproamanita thiersii   [p]    [3.5, 10]        [x]
# 2    Amanitaceae     Amanita russuloides   [p]       [3, 9]        [x]
# 3    Amanitaceae  Amanita flavorubescens   [p]    [4.5, 14]     [x, f]
# 4    Amanitaceae      Amanita flavoconia   [p]       [3, 9]     [x, f]
# ..           ...                     ...   ...          ...        ...
# 94  Pleurotaceae       Pleurotus dryinus   [e]      [4, 12]        [x]
# 95  Pleurotaceae   Pleurotus pulmonarius   [e]      [2, 12]     [x, f]
# 96    Mycenaceae      Panellus stipticus   [p]       [1, 3]        [x]
# 97   Discinaceae   Gyromitra caroliniana   [e]      [5, 10]        [o]
# 98  Helvellaceae        Helvella sulcata   [p]       [1, 5]        [o]
#
#      cap-surface  cap-color does-bruise-or-bleed gill-attachment gill-spacing  \
# ...

# %%
df.drop(columns=['stem-root', 'stem-surface', 'veil-type', 'veil-color', 'spore-print-color'], inplace=True)
df
# Out:
#           family                    name class cap-diameter  cap-shape  \
# 0    Amanitaceae        Amanita vaginata   [e]      [5, 10]  [c, x, f]
# 1    Amanitaceae   Saproamanita thiersii   [p]    [3.5, 10]        [x]
# 2    Amanitaceae     Amanita russuloides   [p]       [3, 9]        [x]
# 3    Amanitaceae  Amanita flavorubescens   [p]    [4.5, 14]     [x, f]
# 4    Amanitaceae      Amanita flavoconia   [p]       [3, 9]     [x, f]
# ..           ...                     ...   ...          ...        ...
# 94  Pleurotaceae       Pleurotus dryinus   [e]      [4, 12]        [x]
# 95  Pleurotaceae   Pleurotus pulmonarius   [e]      [2, 12]     [x, f]
# 96    Mycenaceae      Panellus stipticus   [p]       [1, 3]        [x]
# 97   Discinaceae   Gyromitra caroliniana   [e]      [5, 10]        [o]
# 98  Helvellaceae        Helvella sulcata   [p]       [1, 5]        [o]
#
#      cap-surface  cap-color does-bruise-or-bleed gill-attachment gill-spacing  \
# ...

# %%
df.to_csv("north_american_primary_data.csv", sep=";")
